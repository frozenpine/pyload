# %%
from datetime import datetime

ts_base = 1288834974657

order_id = 1182574587691409409

order_ts = datetime.fromtimestamp(((order_id >> 22) + ts_base) / 1000)

print(order_ts)
# Out:
# 2019-10-11 16:32:07.536000
